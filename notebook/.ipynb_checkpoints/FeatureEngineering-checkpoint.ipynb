# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import warnings
import ppscore as pps
import statsmodels.api as sm

from sklearn.model_selection import train_test_split
import sklearn.metrics
from feature_engine import categorical_encoders as ce
from feature_engine import variable_transformers as vt

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.feature_selection import RFECV
from sklearn import linear_model
from sklearn.preprocessing import MinMaxScaler, StandardScaler

warnings.simplefilter("ignore")
# %matplotlib inline

# %% [markdown]
# Steps:
# - Natural Log Normalize House Price -> then turn back after prediction
# - Combine temporal variables (remove garage as it can be detected from hasGarage)
# - Missing Values -> Fill with Missing, except for PoolQC, Alley etc change to binary
# - Categorical to dummy variables

# %% [markdown]
# ### Read Data

# %%
train = pd.read_csv("../data/train.csv", index_col = [0])
test = pd.read_csv("../data/test.csv", index_col = [0])

# %% [markdown]
# ### Group Each Variables

# %%
temporal = [var for var in train.columns if ("Yr" in var) 
        or ("Mo" in var) or ("Year" in var)]

levels = ["OverallCond", "OverallQual", "BsmtFullBath", 
          "BsmtHalfBath", "FullBath", "HalfBath", 
          "BedroomAbvGr", "KitchenAbvGr", "TotRmsAbvGrd", 
          "Fireplaces", "GarageCars", "ExterQual", 
          "ExterCond", "BsmtQual", "BsmtCond", 
          "BsmtExposure", "HeatingQC", "KitchenQual", 
          "GarageQual","GarageCond", "ExterQual",
          "ExterCond", "BsmtQual", "BsmtCond", 
          "BsmtExposure","HeatingQC", "PoolQC", 
          "KitchenQual", "GarageQual","GarageCond", "FireplaceQu"]

categorical = [var for var in train.columns if (train[var].dtype =='O') 
               and (var not in temporal)
              and (var not in levels)] + ["MSSubClass"]

numerical = [var for var in train.columns if (train[var].dtype !='O') 
             and (var not in temporal) 
             and (var not in levels) and (var != "SalePrice") and (var != "MSSubClass")]
numerical_level = levels + numerical

# %% [markdown]
# ### Convert Group to Rankings

# %%
## categorical to levels conversion
train["ExterQual"] = train["ExterQual"].map({"None":0,"Po":1, "Fa":2, "TA":3, "Gd":4, "Ex":5})
train["ExterCond"] = train["ExterCond"].map({"None":0,"Po":1, "Fa":2, "TA":3, "Gd":4, "Ex":5})
train["BsmtQual"] = train["BsmtQual"].map({"None":0,"Po":1, "Fa":2, "TA":3, "Gd":4, "Ex":5})
train["BsmtCond"] = train["BsmtCond"].map({"None":0,"Po":1, "Fa":2, "TA":3, "Gd":4, "Ex":5})
train["BsmtExposure"] = train["BsmtExposure"].map({"None":0,"Po":1, "Fa":2, "TA":3, "Gd":4, "Ex":5})
train["HeatingQC"] = train["HeatingQC"].map({"None":0,"Po":1, "Fa":2, "TA":3, "Gd":4, "Ex":5})
train["PoolQC"] = train["PoolQC"].map({"None":0,"Po":1, "Fa":2, "TA":3, "Gd":4, "Ex":5})
train["KitchenQual"] = train["KitchenQual"].map({"None":0,"Po":1, "Fa":2, "TA":3, "Gd":4, "Ex":5})
train["GarageQual"] = train["GarageQual"].map({"None":0,"Po":1, "Fa":2, "TA":3, "Gd":4, "Ex":5})
train["GarageCond"] = train["GarageCond"].map({"None":0,"Po":1, "Fa":2, "TA":3, "Gd":4, "Ex":5})
train["FireplaceQu"] = train["FireplaceQu"].map({"None":0,"Po":1, "Fa":2, "TA":3, "Gd":4, "Ex":5})

## convert MSSubclass to categorical
train["MSSubClass"] = train["MSSubClass"].astype(str)

# %%
def combine_temporal(X_train, X_test):
    X_train["n_temp_houseAge"] = \
    X_train["YrSold"] - X_train["YearBuilt"]
    X_train["n_temp_lastRemodelled"] = \
    X_train["YrSold"] - X_train["YearRemodAdd"]
    X_train["n_temp_garageAge"] = \
    X_train["YrSold"] - X_train["GarageYrBlt"]
    
    X_test["n_temp_houseAge"] = \
    X_test["YrSold"] - X_test["YearBuilt"]
    X_test["n_temp_lastRemodelled"] = \
    X_test["YrSold"] - X_test["YearRemodAdd"]
    X_test["n_temp_garageAge"] = \
    X_test["YrSold"] - X_test["GarageYrBlt"]
    
    cols = ["YrSold",
           "YearBuilt",
           "YearRemodAdd",
            "GarageYrBlt"]
    
    return X_train.drop(cols, axis = 1), X_test.drop(cols, axis = 1)

def fill_with_median(X_train, X_test, variable):
    median = X_train[variable].median()
    X_train[variable] = X_train[variable].fillna(median)
    X_test[variable] = X_test[variable].fillna(median)
    return X_train, X_test

def fill_zero(X_train, X_test, variable):
    X_train[variable] = X_train[variable].fillna(0)
    X_test[variable] = X_test[variable].fillna(0)
    return X_train, X_test

def fill_with_missing(X_train, X_test, variable):
    X_train[variable] = X_train[variable].fillna("Missing")
    X_test[variable] = X_test[variable].fillna("Missing")
    return X_train, X_test

def fill_with_mode_from_train(X_train, X_test, variable):
    mode = X_train[variable].mode().iloc[0]
    X_train[variable] = X_train[variable].fillna(mode)
    X_test[variable] = X_test[variable].fillna(mode)
    return X_train, X_test

def find_non_rare_labels(df, variable, tolerance):
    temp = df.groupby([variable])[variable].count()/len(df)
    non_rare = [x for x in temp.loc[temp > tolerance].index.values]
    return non_rare

def rare_encoding(X_train, X_test, variable, tolerance):
    encoder = ce.RareLabelCategoricalEncoder(tol=0.03, 
                                             n_categories=2,
                                             variables=variable,
                                             replace_with='Rare', 
                                             return_object=True)
    # fit the encoder
    encoder.fit(X_train)
    return encoder.transform(X_train), encoder.transform(X_test)

def one_hot_encoding(X_train, X_test, variable):
    encoder = ce.OneHotCategoricalEncoder(
        top_categories = None,
        variables = categorical,
        drop_last = True)
    encoder.fit(X_train)
    return encoder.transform(X_train), encoder.transform(X_test)

def label_encoding(X_train, 
                   y_train,
                   X_test, 
                   variable, 
                   encoding_method):
    encoder = ce.OrdinalCategoricalEncoder(
        encoding_method = encoding_method,
        variables = variable)
    
    if encoding_method == "ordered":
        encoder.fit(X_train, y_train)
    else:
        encoder.fit(X_train)
    return encoder.transform(X_train), encoder.transform(X_test)

def power_transformer(X_train, X_test, variable):
    tf = vt.PowerTransformer(variables = variable, exp=0.5)
    tf.fit(X_train)
    return tf.transform(X_train), tf.transform(X_test)


def boxcox_transformer(X_train, X_test, variable):
    tf = vt.BoxCoxTransformer(variables = variable)
    tf.fit(X_train)
    return tf.transform(X_train), tf.transform(X_test)

def log_transformer(data):
    return np.log(data)

# %%
pd.DataFrame(train[numerical].skew())
# Out:
#                        0
# LotFrontage     2.163569
# LotArea        12.207688
# MasVnrArea      2.669084
# BsmtFinSF1      1.685503
# BsmtFinSF2      4.255261
# BsmtUnfSF       0.920268
# TotalBsmtSF     1.524255
# 1stFlrSF        1.376757
# 2ndFlrSF        0.813030
# LowQualFinSF    9.011341
# GrLivArea       1.366560
# GarageArea      0.179981
# WoodDeckSF      1.541376
# OpenPorchSF     2.364342
# EnclosedPorch   3.089872
# 3SsnPorch      10.304342
# ScreenPorch     4.122214
# PoolArea       14.828374
# MiscVal        24.476794

# %% [markdown]
# ## Train Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(train.drop(["SalePrice"], axis = 1), train["SalePrice"], 
                                                    test_size=0.25, 
                                                    random_state=100)

# %% [markdown]
# ### Breakdown of Steps
# 1. Log Transform each Skewed Variables
# 2. Combine Temporal Features
# 3. Fill NA with median for temporal features (0 does not make any sense)
# 4. Fill numerical/ranking features with 0
# 5. Fill categorical with missing (Except Electrical, fill with mode of the category)
# 6.

# %% [markdown]
# ### Run Models

# %%
def model_OHE(X_train, X_test):

    X_train, X_test = combine_temporal(X_train, X_test)
    X_train, X_test = fill_with_median(X_train, X_test, "n_temp_garageAge")
    X_train, X_test = fill_zero(X_train, X_test, numerical + levels)
    X_train, X_test = fill_with_missing(X_train, X_test,
                                        ["Alley", "MasVnrType", 
                                         "BsmtFinType1", "BsmtFinType2", 
                                         "GarageType", "GarageFinish", 
                                         "Fence", "MiscFeature"])
    X_train, X_test = fill_with_mode_from_train(X_train, X_test, 
                                                ["Electrical"])
    X_train, X_test = rare_encoding(X_train, X_test, categorical, 0.05)
    X_train, X_test = one_hot_encoding(X_train, X_test, categorical)
    scaler = MinMaxScaler().fit(X = X_train[numerical])
    X_train[numerical] = scaler.transform(X_train[numerical])
    X_test[numerical] = scaler.transform(X_test[numerical])
    return X_train, X_test



def model_encode_order_label(X_train, X_test):

    X_train, X_test = combine_temporal(X_train, X_test)
    X_train, X_test = fill_with_median(X_train, X_test, "n_temp_garageAge")
    X_train, X_test = fill_zero(X_train, X_test, numerical + levels)
    X_train, X_test = fill_with_missing(X_train, X_test,
                                        ["Alley", "MasVnrType", 
                                         "BsmtFinType1", "BsmtFinType2", 
                                         "GarageType", "GarageFinish", 
                                         "Fence", "MiscFeature"])
    X_train, X_test = fill_with_mode_from_train(X_train, X_test, 
                                                ["Electrical"])
    X_train, X_test = rare_encoding(X_train, X_test, categorical, 0.05)
    X_train, X_test = label_encoding(X_train, y_train, X_test, 
                                     categorical, "ordered")
    scaler = MinMaxScaler().fit(X = X_train[numerical])
    X_train[numerical] = scaler.transform(X_train[numerical])
    X_test[numerical] = scaler.transform(X_test[numerical])
    return X_train, X_test


def assess_performance(X_train, 
                        X_test, 
                        y_train, 
                        y_test):
    
    
    LR = LinearRegression().fit(X_train, np.log(y_train))
    
    Lasso = linear_model.Lasso(alpha = 1).fit(X_train, np.log(y_train))
    Ridge = linear_model.Ridge(alpha = 1).fit(X_train, np.log(y_train))
    DT = DecisionTreeRegressor(random_state = 100, 
                               max_depth = 4).fit(X_train, y_train)
    RF = RandomForestRegressor(random_state = 100,
                               n_estimators = 50,
                               max_depth = 5).fit(X_train, y_train)
    GB = GradientBoostingRegressor(random_state= 100,
                                   n_estimators = 100,
                                   max_depth = 5).fit(X_train, y_train)
    
    result = {}
    for model, name in zip([LR, Lasso, Ridge], ["LinearRegression",
                                                "Ridge",
                                                "LASSO"]):
        result[name.split("_")[0] + "_8cv_median_r2"] = np.median(
            cross_val_score(model, X_train, np.log(y_train), scoring = "r2", cv = 8))
        result[name.split("_")[0] + "_test_set_r2"] = \
            sklearn.metrics.r2_score(np.exp(model.predict(X_test)), y_test)
    return result

# %%
X_train_encode, X_test_encode= \
    model_encode_order_label(X_train, X_test)

X_train_OHE, X_test_OHE= \
    model_OHE(X_train, X_test)

# %%
result = pd.concat([pd.DataFrame([assess_performance(X_train_OHE, 
                                 X_test_OHE, 
                                 y_train, 
                                 y_test)], index = ["OHE"]),
                    pd.DataFrame([assess_performance(X_train_encode, 
                                 X_test_encode, 
                                 y_train, 
                                 y_test)], index = ["ordered_label"])]).T

# %%
result
# Out:
#                                      OHE  ordered_label
# LinearRegression_8cv_median_r2  0.871592       0.879289
# LinearRegression_test_set_r2    0.845260       0.847420
# Ridge_8cv_median_r2             0.433662       0.433662
# Ridge_test_set_r2              -2.889088      -2.889088
# LASSO_8cv_median_r2             0.879720       0.885155
# LASSO_test_set_r2               0.857209       0.850986

# %%
model = linear_model.Lasso(alpha = 1)

# %%
fit_OHE = RFECV(model, 
              step = 1, 
              cv   = 8,
             scoring = "r2").fit(X_train_OHE, np.log(y_train))

fit_ord_label = RFECV(model, 
              step = 1, 
              cv   = 8,
             scoring = "r2").fit(X_train_encode, np.log(y_train))

# %%
import matplotlib.pyplot as plt

# %%
plt.figure()
plt.xlabel("Number of features selected")
plt.ylabel("Adjusted R2 Score")
plt.plot(range(1, len(fit_OHE.grid_scores_) + 1), fit_OHE.grid_scores_)
sns.despine()
plt.show()

# %%
plt.figure()
plt.xlabel("Number of features selected")
plt.ylabel("Adjusted R2 Score")
plt.plot(range(1, len(fit_ord_label.grid_scores_) + 1), 
         fit_ord_label.grid_scores_, marker = "o")
plt.axvline(x = len(np.where(fit_ord_label.ranking_ == 1)[0]), 
            linestyle = "-.", 
            color = "r", 
            label = "Optimal Line")
plt.title("Assessment Using RFECV (Ridge Regression)")
sns.despine()
plt.legend()
plt.show()

# %%
X_train3.columns[np.where(fit_ord_label.support_ == True)[0]]
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'MasVnrArea', 'ExterQual', 'ExterCond',
#        'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
#        'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF',
#        '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath',
#        'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond',
# ...

# %%
plt.figure()
plt.xlabel("Number of features selected")
plt.ylabel("Adjusted R2 Score")
plt.plot(range(1, len(fit_ord_label_no_log.grid_scores_) + 1), fit_ord_label_no_log.grid_scores_, marker = "o")
plt.axvline(x = 40, linestyle = "-.", color = "r", label = "Optimal Line")
plt.title("Assessment Using RFECV (Ridge Regression)")
sns.despine()
plt.legend()
plt.show()

# %%
def plot_lm(y_test, y_pred, title):
    result = pd.concat([pd.DataFrame(y_test).rename({"SalePrice":"SalePrice True Values"},
                                                    axis = 1).reset_index(drop = True), 
                        pd.DataFrame(y_pred).rename({0:"SalePrice Predicted Values"}, 
                                                    axis = 1).reset_index(drop = True)], axis = 1)
    sns.lmplot(x = "SalePrice True Values", 
               y = "SalePrice Predicted Values", data = result, height=5, aspect=1.6, 
               line_kws={'color': 'red', 'linestyle':'-.'})
    plt.title("Adjusted R2 Score: {} ({})".format(sklearn.metrics.r2_score(y_pred,y_test), title))
    sns.despine()
    plt.show()
    return result

# %%
plot_lm(y_test, 
        model.fit(X_train3, y_train).predict(X_test3), 
        "Not Log Transformed")
plt.show()

# %%
plot_lm(y_test, 
        np.exp(model.fit(X_train3, np.log(y_train)).predict(X_test3)), 
        "Not Log Transformed")
plt.show()

# %%
plot_lm(y_test, 
        model.fit(X_train3[["SaleType", "SaleCondition"]], 
                  y_train).predict(X_test3[["SaleType", "SaleCondition"]]), 
        "Baseline")
plt.show()

# %% [markdown]
# ## Plotting Effect

# %%
model = linear_model.Ridge(alpha = 1)

# %%
new_cols = X_train3.columns[np.where(fit_ord_label.support_ == True)[0]]

# %%
fit = model.fit(X_train3[new_cols], np.log(y_train))
sklearn.metrics.r2_score(np.exp(fit.predict(X_test3[new_cols])), y_test)
# Out:
# 0.8688510150653038

# %%
fit = model.fit(X_train3, np.log(y_train))

# %%
coef_series = pd.Series(fit.coef_, index = X_train3.columns).sort_values()

plt.figure(figsize = (20,5))
coef_series.plot(kind = "bar")
plt.axhline(y = 0, linestyle = "-.", color = "r")
sns.despine()

plt.title("Coefficients of Ridge Regression")
plt.ylabel("Coefficient Weights")
plt.show()

# %%
data = X_train3.copy()
for col in X_train3.columns:
    weights = coef_series.loc[col]
    data[col] = data[col] * weights

# %%
plt.figure(figsize = (20,8))
data.boxplot(rot = 90)
plt.tight_layout()
sns.despine()
plt.show()

# %%
X_train3
# Out:
#      MSSubClass  MSZoning  LotFrontage   LotArea  Street  Alley  LotShape  \
# Id
# 775          20         2     0.351438  0.060417       1      2         0
# 93           30         2     0.255591  0.056370       1      0         1
# 361          85         2     0.000000  0.029166       1      2         1
# 550          60         3     0.239617  0.037743       1      2         0
# 547          50         2     0.223642  0.034761       1      2         1
# ..          ...       ...          ...       ...     ...    ...       ...
# 803          60         2     0.201278  0.032247       1      2         0
# 54           20         2     0.217252  0.228895       1      2         1
# 351         120         2     0.217252  0.030475       1      2         1
# 80           50         1     0.191693  0.042721       1      0         0
# 793          60         2     0.293930  0.040291       1      2         1
#
#      LandContour  Utilities  LotConfig  ...  PoolQC  Fence  MiscFeature  \
# ...

# %%
X_train3
# Out:
#      MSSubClass  MSZoning  LotFrontage     LotArea  Street  Alley  LotShape  \
# Id
# 775          20         2    10.488088  119.272797       1      2         0
# 93           30         2     8.944272  115.585466       1      0         1
# 361          85         2     0.000000   86.833173       1      2         1
# 550          60         3     8.660254   96.824584       1      2         0
# 547          50         2     8.366600   93.471921       1      2         1
# ..          ...       ...          ...         ...     ...    ...       ...
# 803          60         2     7.937254   90.548330       1      2         0
# 54           20         2     8.246211  224.211953       1      2         1
# 351         120         2     8.246211   88.430764       1      2         1
# 80           50         1     7.745967  102.176318       1      0         0
# 793          60         2     9.591663   99.599197       1      2         1
#
# ...
